# %% [markdown]
# # Pandas II - 17/07

# %% [markdown]
# 1. Id cargando todos los ficheros en vuestro jupyter.

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("data/quejas.csv", sep = ";", encoding = "ISO-8859-1")
df1.head()
# Out:
#     tipo                   estado canal_entrada        fecha_entrada  \
# 0  Queja  Recepcionada por Unidad      INTERNET  2022-01-28 00:00:00
# 1  Queja  Recepcionada por Unidad      INTERNET  2022-03-28 00:00:00
# 2  Queja  Recepcionada por Unidad      INTERNET  2022-03-23 00:00:00
# 3  Queja  Recepcionada por Unidad      INTERNET  2022-01-24 00:00:00
# 4  Queja  Recepcionada por Unidad      INTERNET  2022-03-29 00:00:00
#
#   fecha_contestacion                                         consejeria  \
# 0                NaN  Consejería de Medio Ambiente, Vivienda y Agric...
# 1                NaN  Consejería de Medio Ambiente, Vivienda y Agric...
# 2                NaN  Consejería de Medio Ambiente, Vivienda y Agric...
# 3                NaN  Consejería de Medio Ambiente, Vivienda y Agric...
# 4                NaN  Consejería de Medio Ambiente, Vivienda y Agric...
#
#                                  unidad_descripcion     tema subtema
# ...

# %%
df2 = pd.read_excel("data/quejas2.xlsx")
df2.head()
# Out:
#         DESCRIPCION_TEMA                                DESCRIPCION_SUBTEMA
# 0  ATENCIÓN AL CIUDADANO                         ADMINISTRACIÓN ELECTRÓNICA
# 1  ATENCIÓN AL CIUDADANO                                    FUNCIÓN PÚBLICA
# 2  ATENCIÓN AL CIUDADANO  OFICINAS DE ATENCIÓN AL CIUDADANO DE LA COMUNI...
# 3  ATENCIÓN AL CIUDADANO     OFICINAS DE REGISTRO DE LA COMUNIDAD DE MADRID
# 4  ATENCIÓN AL CIUDADANO                                              OTROS

# %%
df3 = pd.read_json("data/quejas.json")
df3.head()
# Out:
#                                                 data
# 0  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 1  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 2  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 3  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 4  {'unidad_descripcion': 'D.G. de Descarbonizaci...

# %%
df_sugerencias = df1.loc[df1["tipo"] == "Sugerencia"]
df_sugerencias.head()
# Out:
#           tipo                   estado canal_entrada        fecha_entrada  \
# 5   Sugerencia  Contestada al Ciudadano      INTERNET  2022-03-08 00:00:00
# 7   Sugerencia  Contestada al Ciudadano      INTERNET  2022-01-24 00:00:00
# 34  Sugerencia  Contestada al Ciudadano      INTERNET  2022-03-28 00:00:00
# 37  Sugerencia  Contestada al Ciudadano      INTERNET  2022-01-10 00:00:00
# 40  Sugerencia  Recepcionada por Unidad      INTERNET  2022-03-28 00:00:00
#
#      fecha_contestacion                                         consejeria  \
# 5   2022-03-14 00:00:00  Consejería de Medio Ambiente, Vivienda y Agric...
# 7   2022-02-01 00:00:00  Consejería de Medio Ambiente, Vivienda y Agric...
# 34  2022-03-31 00:00:00  Consejería de Educación, Universidades, Cienci...
# 37  2022-01-12 00:00:00  Consejería de Educación, Universidades, Cienci...
# 40                  NaN  Consejería de Educación, Universidades, Cienci...
#
# ...

# %%
cond1= df1["tipo"] == "Queja"
cond2= df1["canal_entrada"] == "PRESENCIAL"
df_queja_presencial = df1.loc[cond1 & cond2, ["fecha_entrada", "fecha_contestacion"]]
df_queja_presencial.head()
# Out:
#            fecha_entrada   fecha_contestacion
# 45   2022-01-31 00:00:00                  NaN
# 197  2022-02-17 00:00:00  2022-02-23 00:00:00
# 420  2022-02-14 00:00:00  2022-02-15 00:00:00
# 421  2022-02-11 00:00:00  2022-02-11 00:00:00
# 422  2022-02-14 00:00:00  2022-02-15 00:00:00

# %% [markdown]
# 2. Para poner el práctica el read_clipboard en esta página web os encontraréis una tabla similar a esta que os mostramos a continuación 👇:
#
#    Usando el método read_clipboard, cread un dataframe nuevo que nos ayude a contestar las siguientes preguntas:
#    * Usando el iloc, ¿Cuál es la temperatura mínima de Febrero? ¿Y la máxima?
#    * Usando el loc, ¿Cuántas horas de sol hay en Julio? ¿Y en Diciembre?
#    * Usando el iloc, ¿Cuál fue la húmedad del mes de Septiembre? ¿Y la precipitación?
#    * Estos datos corresponden a los años 1991-2021. Cread una nueva columna cuyo valor sea "1991-2021".

# %%
df4 = pd.read_clipboard()
df4
# Out:
#                        Enero Febrero Marzo Abril  Mayo Junio ​​Julio Agosto  \
# Temperatura media (°C)   4.8       6   9.2  12.2  16.7  22.8      26   25.6
# Temperatura min. (°C)    0.9     1.4   3.8   6.4  10.3  15.7    18.8   18.5
# Temperatura máx. (°C)    9.5    11.4    15  17.9  22.6    29    32.4   31.9
# Precipitación (mm)        41      34    40    47    39    16       6      8
# Humedad(%)               77%     69%   60%   57%   48%   35%     28%    30%
# Días lluviosos (días)      5       4     4     6     5     3       1      2
# Horas de sol (horas)     5.7     6.8   8.1   9.4  11.5  13.0    13.1   12.1
#
#                        Septiembre Octubre Noviembre Diciembre
# Temperatura media (°C)       20.9    15.1       8.6       5.5
# Temperatura min. (°C)        14.8    10.2       4.7       1.8
# Temperatura máx. (°C)        26.8    20.3      13.2      10.1
# Precipitación (mm)             22      61        55        46
# ...

# %%
df4.head()
# Out:
#                        Enero Febrero Marzo Abril  Mayo Junio ​​Julio Agosto  \
# Temperatura media (°C)   4.8       6   9.2  12.2  16.7  22.8      26   25.6
# Temperatura min. (°C)    0.9     1.4   3.8   6.4  10.3  15.7    18.8   18.5
# Temperatura máx. (°C)    9.5    11.4    15  17.9  22.6    29    32.4   31.9
# Precipitación (mm)        41      34    40    47    39    16       6      8
# Humedad(%)               77%     69%   60%   57%   48%   35%     28%    30%
#
#                        Septiembre Octubre Noviembre Diciembre
# Temperatura media (°C)       20.9    15.1       8.6       5.5
# Temperatura min. (°C)        14.8    10.2       4.7       1.8
# Temperatura máx. (°C)        26.8    20.3      13.2      10.1
# Precipitación (mm)             22      61        55        46
# Humedad(%)                    41%     60%       72%       77%

# %%
df4.iloc[[1,2],1]
# Out:
# Temperatura min. (°C)     1.4
# Temperatura máx. (°C)    11.4
# Name: Febrero, dtype: object

# %%
df4.loc['Horas de sol (horas)',["​​Julio","Diciembre"]]
# Out:
# ​​Julio      13.1
# Diciembre     5.7
# Name: Horas de sol (horas), dtype: object

# %%
df4.iloc[[3,4], 8]
# Out:
# Precipitación (mm)     22
# Humedad(%)            41%
# Name: Septiembre, dtype: object

# %%
df4["Año"] = "1991/2021"
df4.head()
# Out:
#                        Enero Febrero Marzo Abril  Mayo Junio ​​Julio Agosto  \
# Temperatura media (°C)   4.8       6   9.2  12.2  16.7  22.8      26   25.6
# Temperatura min. (°C)    0.9     1.4   3.8   6.4  10.3  15.7    18.8   18.5
# Temperatura máx. (°C)    9.5    11.4    15  17.9  22.6    29    32.4   31.9
# Precipitación (mm)        41      34    40    47    39    16       6      8
# Humedad(%)               77%     69%   60%   57%   48%   35%     28%    30%
#
#                        Septiembre Octubre Noviembre Diciembre        Año
# Temperatura media (°C)       20.9    15.1       8.6       5.5  1991/2021
# Temperatura min. (°C)        14.8    10.2       4.7       1.8  1991/2021
# Temperatura máx. (°C)        26.8    20.3      13.2      10.1  1991/2021
# Precipitación (mm)             22      61        55        46  1991/2021
# Humedad(%)                    41%     60%       72%       77%  1991/2021

# %% [markdown]
# 3. Por último, guardad el dataframe generado en el ejercicio 2 en formato csv y xlsx.

# %%
df4.to_csv("data/datosclimaticos.csv")
df4.to_excel("data/datosclimaticos.xlsx")
